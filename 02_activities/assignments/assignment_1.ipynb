# %% [markdown]
# # Working with parquet files
#
# ## Objective
#
# + In this assignment, we will use the data downloaded with the module `data_manager` to create features.
#
# (11 pts total)
#
# ## Prerequisites
#
# + This notebook assumes that price data is available to you in the environment variable `PRICE_DATA`. If you have not done so, then execute the notebook `01_materials/labs/2_data_engineering.ipynb` to create this data set.

# %% [markdown]
# + Load the environment variables using dotenv. (1 pt)

# %%
# Write your code below.
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import dask.dataframe as dd

# %% [markdown]
# + Load the environment variable `PRICE_DATA`.
# + Use [glob](https://docs.python.org/3/library/glob.html) to find the path of all parquet files in the directory `PRICE_DATA`.
#
# (1pt)

# %%
import os
from glob import glob

# Write your code below.

#Load the PRICE_DATA environment variable
Price_data = glob(os.path.join(os.getenv('SRC_DIR'), 'data/prices_csv/stocks/*.csv'))

print(Price_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       4 # Write your code below.
#       5
#       6 #Load the PRICE_DATA environment variable
#       7 Price_data = glob(os.path.join(os.getenv('SRC_DIR'), 'data/prices_csv/stocks/*.csv'))
# ----> 9 print(Price_data)
#
# TypeError: 'list' object is not callable

# %%
# Find all .parquet files in the PRICE_DATA directory
parquet_files = glob.glob('PRICE_DATA/*.parquet')

print(parquet_files)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Find all .parquet files in the PRICE_DATA directory
# ----> 2 parquet_files = glob.glob('PRICE_DATA/*.parquet')
#       4 print(parquet_files)
#
# AttributeError: 'function' object has no attribute 'glob'

# %% [markdown]
# For each ticker and using Dask, do the following:
#
# + Add lags for variables Close and Adj_Close.
# + Add returns based on Close:
#
#     - `returns`: (Close / Close_lag_1) - 1
#
# + Add the following range:
#
#     - `hi_lo_range`: this is the day's High minus Low.
#
# + Assign the result to `dd_feat`.
#
# (4 pt)

# %%
import dask.dataframe as dd

# Load all parquet files into a Dask DataFrame
ddf = dd.read_parquet('PRICE_DATA/*.parquet')

ddf.columns = [col.strip().lower() for col in ddf.columns]


# Define feature engineering function
def add_features(df):
    df = df.sort_values('Date') 

    # Add lag for variables
    df['Close_lag_1'] = df['Close'].shift(1)
    df['Adj_Close_lag_1'] = df['Adj_Close'].shift(1)

    # Add returns based on closed
    df['returns'] = (df['Close'] / df['Close_lag_1']) - 1

    # Add the range
    df['hi_lo_range'] = df['High'] - df['Low']

    return df

# Assign to dd feat
dd_feat = ddf.groupby('Ticker').apply(add_features, meta=ddf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 26
#      23     return df
#      25 # Assign to dd feat
# ---> 26 dd_feat = ddf.groupby('Ticker').apply(add_features, meta=ddf)
#
# File c:\Users\grace\miniconda3\envs\dsi_production_only\Lib\site-packages\dask\dataframe\dask_expr\_collection.py:3035, in DataFrame.groupby(self, by, group_keys, sort, observed, dropna, **kwargs)
#    3030 if isinstance(by, FrameBase) and not isinstance(by, Series):
#    3031     raise ValueError(
#    3032         f"`by` must be a column name or list of columns, got {by}."
#    3033     )
# -> 3035 return GroupBy(
#    3036     self,
#    3037     by,
#    3038     group_keys=group_keys,
#    3039     sort=sort,
#    3040     observed=observed,
#    3041     dropna=dropna,
#    3042     **kwargs,
#    3043 )
#
# File c:\Users\grace\miniconda3\envs\dsi_production_only\Lib\site-packages\dask\dataframe\dask_expr\_groupby.py:1562, in GroupBy.__init__(self, obj, by, group_keys, sort, observed, dropna, slice)
#    1558 self.by = (
#    1559     [by] if np.isscalar(by) or isinstance(by, (Expr, Callable)) else list(by)
#    1560 )
#    1561 # surface pandas errors
# -> 1562 self._meta = self.obj._meta.groupby(
#    1563     by,
#    1564     group_keys=group_keys,
#    1565     sort=sort,
#    1566     **_as_dict("observed", observed),
#    1567     **_as_dict("dropna", dropna),
#    1568 )
#    1569 if slice is not None:
#    1570     if isinstance(slice, tuple):
#
# File c:\Users\grace\miniconda3\envs\dsi_production_only\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# File c:\Users\grace\miniconda3\envs\dsi_production_only\Lib\site-packages\pandas\core\groupby\groupby.py:1330, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327 self.dropna = dropna
#    1329 if grouper is None:
# -> 1330     grouper, exclusions, obj = get_grouper(
#    1331         obj,
#    1332         keys,
#    1333         axis=axis,
#    1334         level=level,
#    1335         sort=sort,
#    1336         observed=False if observed is lib.no_default else observed,
#    1337         dropna=self.dropna,
#    1338     )
#    1340 if observed is lib.no_default:
#    1341     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\grace\miniconda3\envs\dsi_production_only\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Ticker'

# %% [markdown]
# + Convert the Dask data frame to a pandas data frame.
# + Add a new feature containing the moving average of `returns` using a window of 10 days. There are several ways to solve this task, a simple one uses `.rolling(10).mean()`.
#
# (3 pt)

# %%
# Write your code below.
import dask.dataframe as dd

# Assume ddf is your Dask DataFrame
ddf = dd.read_parquet('PRICE_DATA/*.parquet')

# Convert to Pandas DataFrame
pdf = ddf.compute()

# %% [markdown]
# Please comment:
#
# + Was it necessary to convert to pandas to calculate the moving average return?
# + Would it have been better to do it in Dask? Why?
#
# (1 pt)

# %%
#Was it necessary to convert to pandas to calculate the moving average return?

#Would it have been better to do it in Dask? Why?

# %% [markdown]
# ## Criteria
#
# The [rubric](./assignment_1_rubric_clean.xlsx) contains the criteria for grading.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
